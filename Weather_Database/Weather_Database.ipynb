# %% [markdown]
# # CHALLENGE: Deliverable 1

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
#Create a set of 2000 random latitudes and longitudes
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lats_lngs = zip(lats, lngs)

# %%
# Add lngs/lats to list
coordinates = list(lats_lngs)

# %%
#City list
cities = []

#Nearest city for each lat/lng.
for coord in coordinates:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    
    #if city not unique then don't add to cities list
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 730

# %%
# Import the requests library.
import requests

from datetime import datetime

# Import the API key.
import sys
sys.path.append('../')
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | akdepe
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | tashla
# Processing Record 4 of Set 1 | touros
# Processing Record 5 of Set 1 | nyurba
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | ust-maya
# Processing Record 8 of Set 1 | marathon
# Processing Record 9 of Set 1 | waipawa
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | aswan
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | aybak
# City not found. Skipping...
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 21 of Set 1 | lagoa
# Processing Record 22 of Set 1 | ossora
# Processing Record 23 of Set 1 | san vicente
# Processing Record 24 of Set 1 | lerici
# Processing Record 25 of Set 1 | pangnirtung
# Processing Record 26 of Set 1 | taksimo
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | tahe
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | los llanos de aridane
# Processing Record 34 of Set 1 | port lincoln
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | kirakira
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | kaeo
# Processing Record 40 of Set 1 | axim
# Processing Record 41 of Set 1 | angoram
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | constitucion
# Processing Record 45 of Set 1 | zenzeli
# Processing Record 46 of Set 1 | manubul
# Processing Record 47 of Set 1 | paragominas
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | norman wells
# Processing Record 1 of Set 2 | chokurdakh
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | porto belo
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | tuatapere
# Processing Record 7 of Set 2 | yertsevo
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | sao filipe
# Processing Record 10 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 2 | port hedland
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | pisco
# Processing Record 15 of Set 2 | san patricio
# Processing Record 16 of Set 2 | bathsheba
# Processing Record 17 of Set 2 | inhambane
# Processing Record 18 of Set 2 | deputatskiy
# Processing Record 19 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | cidreira
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 2 | omaruru
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | rocha
# Processing Record 27 of Set 2 | asau
# Processing Record 28 of Set 2 | erding
# Processing Record 29 of Set 2 | klaksvik
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | nenjiang
# Processing Record 32 of Set 2 | quatre cocos
# Processing Record 33 of Set 2 | sibolga
# Processing Record 34 of Set 2 | pontes e lacerda
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | awbari
# Processing Record 37 of Set 2 | prince rupert
# Processing Record 38 of Set 2 | goundam
# Processing Record 39 of Set 2 | santa maria
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | komsomolskiy
# Processing Record 42 of Set 2 | shache
# Processing Record 43 of Set 2 | bambous virieux
# Processing Record 44 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 2 | sao joao da barra
# Processing Record 46 of Set 2 | dunedin
# Processing Record 47 of Set 2 | baihar
# Processing Record 48 of Set 2 | dingle
# Processing Record 49 of Set 2 | hovd
# Processing Record 50 of Set 2 | santa fe
# Processing Record 1 of Set 3 | siilinjarvi
# Processing Record 2 of Set 3 | de-kastri
# Processing Record 3 of Set 3 | launceston
# Processing Record 4 of Set 3 | ouesso
# Processing Record 5 of Set 3 | vestmannaeyjar
# Processing Record 6 of Set 3 | nanyamba
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 3 | dong hoi
# Processing Record 10 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 11 of Set 3 | san diego de los banos
# Processing Record 12 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 3 | znamenskoye
# Processing Record 14 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 3 | cairns
# Processing Record 16 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | saint-augustin
# Processing Record 20 of Set 3 | omboue
# Processing Record 21 of Set 3 | cape town
# Processing Record 22 of Set 3 | clyde river
# Processing Record 23 of Set 3 | sharjah
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | kruisfontein
# Processing Record 26 of Set 3 | magadan
# Processing Record 27 of Set 3 | chulym
# Processing Record 28 of Set 3 | banda aceh
# Processing Record 29 of Set 3 | qeshm
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | luderitz
# Processing Record 32 of Set 3 | manresa
# Processing Record 33 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 34 of Set 3 | emba
# Processing Record 35 of Set 3 | fortuna
# Processing Record 36 of Set 3 | weligama
# Processing Record 37 of Set 3 | puerto escondido
# Processing Record 38 of Set 3 | berlin
# Processing Record 39 of Set 3 | kudat
# Processing Record 40 of Set 3 | belyy yar
# Processing Record 41 of Set 3 | chuy
# Processing Record 42 of Set 3 | ruidoso
# Processing Record 43 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 46 of Set 3 | sinnamary
# Processing Record 47 of Set 3 | leningradskiy
# Processing Record 48 of Set 3 | sobolevo
# Processing Record 49 of Set 3 | shimoda
# Processing Record 50 of Set 3 | ponta do sol
# Processing Record 1 of Set 4 | marzuq
# Processing Record 2 of Set 4 | bridgetown
# Processing Record 3 of Set 4 | campoverde
# Processing Record 4 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 4 | bara
# Processing Record 6 of Set 4 | waddan
# Processing Record 7 of Set 4 | hasaki
# Processing Record 8 of Set 4 | itamarandiba
# Processing Record 9 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 4 | marsh harbour
# Processing Record 11 of Set 4 | half moon bay
# Processing Record 12 of Set 4 | kokopo
# Processing Record 13 of Set 4 | bengkulu
# Processing Record 14 of Set 4 | agadir
# Processing Record 15 of Set 4 | burica
# City not found. Skipping...
# Processing Record 16 of Set 4 | butaritari
# Processing Record 17 of Set 4 | silver city
# Processing Record 18 of Set 4 | alofi
# Processing Record 19 of Set 4 | goulburn
# Processing Record 20 of Set 4 | east london
# Processing Record 21 of Set 4 | mar del plata
# Processing Record 22 of Set 4 | betong
# Processing Record 23 of Set 4 | tynne
# Processing Record 24 of Set 4 | ariquemes
# Processing Record 25 of Set 4 | brae
# Processing Record 26 of Set 4 | slidell
# Processing Record 27 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 4 | port keats
# Processing Record 29 of Set 4 | khatanga
# Processing Record 30 of Set 4 | kahului
# Processing Record 31 of Set 4 | nantucket
# Processing Record 32 of Set 4 | hithadhoo
# Processing Record 33 of Set 4 | omsukchan
# Processing Record 34 of Set 4 | inirida
# Processing Record 35 of Set 4 | voh
# Processing Record 36 of Set 4 | esperance
# Processing Record 37 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 4 | novovarshavka
# Processing Record 39 of Set 4 | shanghai
# Processing Record 40 of Set 4 | aland
# Processing Record 41 of Set 4 | kotlas
# Processing Record 42 of Set 4 | jacareacanga
# Processing Record 43 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 45 of Set 4 | kumukh
# Processing Record 46 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 4 | arroio do meio
# Processing Record 48 of Set 4 | thinadhoo
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 50 of Set 4 | kaitangata
# Processing Record 1 of Set 5 | santiago
# Processing Record 2 of Set 5 | meulaboh
# Processing Record 3 of Set 5 | porbandar
# Processing Record 4 of Set 5 | orsha
# Processing Record 5 of Set 5 | victoria
# Processing Record 6 of Set 5 | souillac
# Processing Record 7 of Set 5 | tasiilaq
# Processing Record 8 of Set 5 | padang
# Processing Record 9 of Set 5 | cherat
# Processing Record 10 of Set 5 | saldanha
# Processing Record 11 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 5 | san jeronimo
# Processing Record 13 of Set 5 | pyaozerskiy
# Processing Record 14 of Set 5 | bajo baudo
# City not found. Skipping...
# Processing Record 15 of Set 5 | vanersborg
# Processing Record 16 of Set 5 | pemangkat
# Processing Record 17 of Set 5 | port elizabeth
# Processing Record 18 of Set 5 | vysokogornyy
# Processing Record 19 of Set 5 | barrow
# Processing Record 20 of Set 5 | iralaya
# Processing Record 21 of Set 5 | kupang
# Processing Record 22 of Set 5 | morro bay
# Processing Record 23 of Set 5 | kalmunai
# Processing Record 24 of Set 5 | mumford
# Processing Record 25 of Set 5 | canakkale
# Processing Record 26 of Set 5 | cherskiy
# Processing Record 27 of Set 5 | port hardy
# Processing Record 28 of Set 5 | abu dhabi
# Processing Record 29 of Set 5 | kavaratti
# Processing Record 30 of Set 5 | calama
# Processing Record 31 of Set 5 | lorengau
# Processing Record 32 of Set 5 | dromolaxia
# Processing Record 33 of Set 5 | prince george
# Processing Record 34 of Set 5 | pinheiro machado
# Processing Record 35 of Set 5 | qaanaaq
# Processing Record 36 of Set 5 | suluq
# Processing Record 37 of Set 5 | kiama
# Processing Record 38 of Set 5 | dongsheng
# Processing Record 39 of Set 5 | college
# Processing Record 40 of Set 5 | nishihara
# Processing Record 41 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | boende
# Processing Record 44 of Set 5 | tucurui
# Processing Record 45 of Set 5 | husavik
# Processing Record 46 of Set 5 | humaita
# Processing Record 47 of Set 5 | birsk
# Processing Record 48 of Set 5 | avera
# Processing Record 49 of Set 5 | pevek
# Processing Record 50 of Set 5 | hualmay
# Processing Record 1 of Set 6 | provideniya
# Processing Record 2 of Set 6 | sainte-suzanne
# Processing Record 3 of Set 6 | porto novo
# Processing Record 4 of Set 6 | mnogovershinnyy
# Processing Record 5 of Set 6 | ballina
# Processing Record 6 of Set 6 | paamiut
# Processing Record 7 of Set 6 | vanimo
# Processing Record 8 of Set 6 | bairnsdale
# Processing Record 9 of Set 6 | yatou
# Processing Record 10 of Set 6 | longyearbyen
# Processing Record 11 of Set 6 | truckee
# Processing Record 12 of Set 6 | vila
# Processing Record 13 of Set 6 | san cristobal
# Processing Record 14 of Set 6 | kudahuvadhoo
# Processing Record 15 of Set 6 | cortez
# Processing Record 16 of Set 6 | puerto carreno
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | anadyr
# Processing Record 19 of Set 6 | port alfred
# Processing Record 20 of Set 6 | lebu
# Processing Record 21 of Set 6 | egvekinot
# Processing Record 22 of Set 6 | vernon
# Processing Record 23 of Set 6 | davila
# Processing Record 24 of Set 6 | whitehorse
# Processing Record 25 of Set 6 | manggar
# Processing Record 26 of Set 6 | carutapera
# Processing Record 27 of Set 6 | oktyabrskoye
# Processing Record 28 of Set 6 | sorong
# Processing Record 29 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 6 | sao borja
# Processing Record 31 of Set 6 | mersing
# Processing Record 32 of Set 6 | vardo
# Processing Record 33 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 6 | humberto de campos
# Processing Record 35 of Set 6 | san quintin
# Processing Record 36 of Set 6 | nouakchott
# Processing Record 37 of Set 6 | constantine
# Processing Record 38 of Set 6 | payo
# Processing Record 39 of Set 6 | nefteyugansk
# Processing Record 40 of Set 6 | divnoye
# Processing Record 41 of Set 6 | naze
# Processing Record 42 of Set 6 | nizwa
# Processing Record 43 of Set 6 | leshan
# Processing Record 44 of Set 6 | katsuura
# Processing Record 45 of Set 6 | sinop
# Processing Record 46 of Set 6 | hobyo
# Processing Record 47 of Set 6 | carahue
# Processing Record 48 of Set 6 | oranjemund
# Processing Record 49 of Set 6 | novo aripuana
# Processing Record 50 of Set 6 | agirish
# Processing Record 1 of Set 7 | olinda
# Processing Record 2 of Set 7 | wladyslawowo
# Processing Record 3 of Set 7 | mount isa
# Processing Record 4 of Set 7 | las cruces
# Processing Record 5 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 6 of Set 7 | muncar
# Processing Record 7 of Set 7 | lakatoro
# Processing Record 8 of Set 7 | mulege
# Processing Record 9 of Set 7 | faya
# Processing Record 10 of Set 7 | kalino
# Processing Record 11 of Set 7 | bridlington
# Processing Record 12 of Set 7 | ust-barguzin
# Processing Record 13 of Set 7 | itoigawa
# Processing Record 14 of Set 7 | grand gaube
# Processing Record 15 of Set 7 | abu zabad
# Processing Record 16 of Set 7 | hukuntsi
# Processing Record 17 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 7 | makakilo city
# Processing Record 19 of Set 7 | villa bisono
# Processing Record 20 of Set 7 | ixtapa
# Processing Record 21 of Set 7 | poum
# Processing Record 22 of Set 7 | sfantu gheorghe
# Processing Record 23 of Set 7 | jiwani
# Processing Record 24 of Set 7 | trebinje
# Processing Record 25 of Set 7 | terme
# Processing Record 26 of Set 7 | adrar
# Processing Record 27 of Set 7 | batticaloa
# Processing Record 28 of Set 7 | eureka
# Processing Record 29 of Set 7 | gushikawa
# Processing Record 30 of Set 7 | udachnyy
# Processing Record 31 of Set 7 | dosso
# Processing Record 32 of Set 7 | calamar
# Processing Record 33 of Set 7 | constanza
# Processing Record 34 of Set 7 | richards bay
# Processing Record 35 of Set 7 | bonfim
# Processing Record 36 of Set 7 | nago
# Processing Record 37 of Set 7 | mehamn
# Processing Record 38 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 7 | ayame
# Processing Record 40 of Set 7 | camacari
# Processing Record 41 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 7 | ostrovnoy
# Processing Record 43 of Set 7 | bilibino
# Processing Record 44 of Set 7 | wajima
# Processing Record 45 of Set 7 | katherine
# Processing Record 46 of Set 7 | fernley
# Processing Record 47 of Set 7 | hervey bay
# Processing Record 48 of Set 7 | merauke
# Processing Record 49 of Set 7 | barra do garcas
# Processing Record 50 of Set 7 | vao
# Processing Record 1 of Set 8 | port blair
# Processing Record 2 of Set 8 | neiafu
# Processing Record 3 of Set 8 | tual
# Processing Record 4 of Set 8 | klaipeda
# Processing Record 5 of Set 8 | santiago de cao
# Processing Record 6 of Set 8 | maragogi
# Processing Record 7 of Set 8 | xiaoweizhai
# Processing Record 8 of Set 8 | chengde
# Processing Record 9 of Set 8 | cayenne
# Processing Record 10 of Set 8 | snezhnogorsk
# Processing Record 11 of Set 8 | naryan-mar
# Processing Record 12 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 8 | aloleng
# Processing Record 14 of Set 8 | komagane
# Processing Record 15 of Set 8 | mount gambier
# Processing Record 16 of Set 8 | labuhan
# Processing Record 17 of Set 8 | ramsgate
# Processing Record 18 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 8 | havre-saint-pierre
# Processing Record 20 of Set 8 | yerbogachen
# Processing Record 21 of Set 8 | kitimat
# Processing Record 22 of Set 8 | saint-pierre
# Processing Record 23 of Set 8 | northam
# Processing Record 24 of Set 8 | presidencia roque saenz pena
# Processing Record 25 of Set 8 | tessalit
# Processing Record 26 of Set 8 | lasa
# Processing Record 27 of Set 8 | lompoc
# Processing Record 28 of Set 8 | haines junction
# Processing Record 29 of Set 8 | muborak
# Processing Record 30 of Set 8 | okhotsk
# Processing Record 31 of Set 8 | abu kamal
# Processing Record 32 of Set 8 | hastings
# Processing Record 33 of Set 8 | trairi
# Processing Record 34 of Set 8 | akyab
# Processing Record 35 of Set 8 | changji
# Processing Record 36 of Set 8 | batu berendam
# Processing Record 37 of Set 8 | laguna
# Processing Record 38 of Set 8 | churapcha
# Processing Record 39 of Set 8 | abapo
# Processing Record 40 of Set 8 | nicolas bravo
# Processing Record 41 of Set 8 | krasnogvardeyets
# Processing Record 42 of Set 8 | oksfjord
# Processing Record 43 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 8 | hami
# Processing Record 45 of Set 8 | isangel
# Processing Record 46 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 8 | kidodi
# Processing Record 48 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 8 | dodge city
# Processing Record 50 of Set 8 | kenai
# Processing Record 1 of Set 9 | kuusamo
# Processing Record 2 of Set 9 | portland
# Processing Record 3 of Set 9 | limbang
# Processing Record 4 of Set 9 | somers
# Processing Record 5 of Set 9 | mabaruma
# Processing Record 6 of Set 9 | reading
# Processing Record 7 of Set 9 | sorland
# Processing Record 8 of Set 9 | te anau
# Processing Record 9 of Set 9 | roald
# Processing Record 10 of Set 9 | geraldton
# Processing Record 11 of Set 9 | saint-joseph
# Processing Record 12 of Set 9 | talaya
# Processing Record 13 of Set 9 | thanh hoa
# Processing Record 14 of Set 9 | takoradi
# Processing Record 15 of Set 9 | saint-georges
# Processing Record 16 of Set 9 | yerofey pavlovich
# Processing Record 17 of Set 9 | georgetown
# Processing Record 18 of Set 9 | chara
# Processing Record 19 of Set 9 | marawi
# Processing Record 20 of Set 9 | kultuk
# Processing Record 21 of Set 9 | saint-felicien
# Processing Record 22 of Set 9 | korla
# Processing Record 23 of Set 9 | vrangel
# Processing Record 24 of Set 9 | nome
# Processing Record 25 of Set 9 | bundaberg
# Processing Record 26 of Set 9 | cooma
# Processing Record 27 of Set 9 | roma
# Processing Record 28 of Set 9 | fushan
# Processing Record 29 of Set 9 | montepuez
# Processing Record 30 of Set 9 | sisimiut
# Processing Record 31 of Set 9 | bambamarca
# Processing Record 32 of Set 9 | ancud
# Processing Record 33 of Set 9 | barisal
# Processing Record 34 of Set 9 | bagdarin
# Processing Record 35 of Set 9 | manitouwadge
# Processing Record 36 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 37 of Set 9 | russkaya polyana
# Processing Record 38 of Set 9 | coatesville
# Processing Record 39 of Set 9 | santo stino di livenza
# Processing Record 40 of Set 9 | valparaiso
# Processing Record 41 of Set 9 | evensk
# Processing Record 42 of Set 9 | bouna
# Processing Record 43 of Set 9 | effingham
# Processing Record 44 of Set 9 | sabang
# Processing Record 45 of Set 9 | saurimo
# Processing Record 46 of Set 9 | faanui
# Processing Record 47 of Set 9 | jember
# Processing Record 48 of Set 9 | xuddur
# Processing Record 49 of Set 9 | hofn
# Processing Record 50 of Set 9 | dicabisagan
# Processing Record 1 of Set 10 | yulara
# Processing Record 2 of Set 10 | ambunti
# Processing Record 3 of Set 10 | bontang
# Processing Record 4 of Set 10 | kieta
# Processing Record 5 of Set 10 | dogondoutchi
# Processing Record 6 of Set 10 | pedasi
# Processing Record 7 of Set 10 | havoysund
# Processing Record 8 of Set 10 | mackay
# Processing Record 9 of Set 10 | karasburg
# Processing Record 10 of Set 10 | letka
# Processing Record 11 of Set 10 | penzance
# Processing Record 12 of Set 10 | guiratinga
# Processing Record 13 of Set 10 | tuktoyaktuk
# Processing Record 14 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 10 | marataizes
# Processing Record 16 of Set 10 | arica
# Processing Record 17 of Set 10 | olafsvik
# Processing Record 18 of Set 10 | belaya gora
# Processing Record 19 of Set 10 | mahebourg
# Processing Record 20 of Set 10 | qandahar
# City not found. Skipping...
# Processing Record 21 of Set 10 | high level
# Processing Record 22 of Set 10 | mokhsogollokh
# Processing Record 23 of Set 10 | jieshi
# Processing Record 24 of Set 10 | san mateo del mar
# Processing Record 25 of Set 10 | matagami
# Processing Record 26 of Set 10 | lavrentiya
# Processing Record 27 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 10 | singapore
# Processing Record 29 of Set 10 | amahai
# Processing Record 30 of Set 10 | panguna
# Processing Record 31 of Set 10 | pacific grove
# Processing Record 32 of Set 10 | asosa
# Processing Record 33 of Set 10 | ascension
# Processing Record 34 of Set 10 | knoxville
# Processing Record 35 of Set 10 | bethel
# Processing Record 36 of Set 10 | caarapo
# Processing Record 37 of Set 10 | krasnyy chikoy
# Processing Record 38 of Set 10 | senador guiomard
# Processing Record 39 of Set 10 | tecoanapa
# Processing Record 40 of Set 10 | boundiali
# Processing Record 41 of Set 10 | polunochnoye
# Processing Record 42 of Set 10 | srinagar
# Processing Record 43 of Set 10 | svetlogorsk
# Processing Record 44 of Set 10 | kismayo
# Processing Record 45 of Set 10 | patnos
# Processing Record 46 of Set 10 | mata
# Processing Record 47 of Set 10 | talcahuano
# Processing Record 48 of Set 10 | mayor pablo lagerenza
# Processing Record 49 of Set 10 | juru
# Processing Record 50 of Set 10 | los alamos
# Processing Record 1 of Set 11 | portobelo
# Processing Record 2 of Set 11 | guanica
# Processing Record 3 of Set 11 | riviere-du-loup
# Processing Record 4 of Set 11 | vila franca do campo
# Processing Record 5 of Set 11 | wittmund
# Processing Record 6 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 11 | kamaishi
# Processing Record 8 of Set 11 | aklavik
# Processing Record 9 of Set 11 | nacala
# Processing Record 10 of Set 11 | meadville
# Processing Record 11 of Set 11 | sechura
# Processing Record 12 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 11 | airai
# Processing Record 14 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 15 of Set 11 | mikuni
# Processing Record 16 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 11 | guerrero negro
# Processing Record 18 of Set 11 | san ramon
# Processing Record 19 of Set 11 | bonavista
# Processing Record 20 of Set 11 | izumo
# Processing Record 21 of Set 11 | kologriv
# Processing Record 22 of Set 11 | saint-louis
# Processing Record 23 of Set 11 | yingzhong
# City not found. Skipping...
# Processing Record 24 of Set 11 | muros
# Processing Record 25 of Set 11 | broken hill
# Processing Record 26 of Set 11 | abeche
# Processing Record 27 of Set 11 | lakes entrance
# Processing Record 28 of Set 11 | obihiro
# Processing Record 29 of Set 11 | kysyl-syr
# Processing Record 30 of Set 11 | bolshaya irba
# City not found. Skipping...
# Processing Record 31 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 32 of Set 11 | port-gentil
# Processing Record 33 of Set 11 | sakakah
# Processing Record 34 of Set 11 | zlobin
# Processing Record 35 of Set 11 | baherden
# Processing Record 36 of Set 11 | haapu
# City not found. Skipping...
# Processing Record 37 of Set 11 | qaqortoq
# Processing Record 38 of Set 11 | oranjestad
# Processing Record 39 of Set 11 | villa bruzual
# Processing Record 40 of Set 11 | ulety
# Processing Record 41 of Set 11 | gilleleje
# Processing Record 42 of Set 11 | kholtoson
# Processing Record 43 of Set 11 | alice springs
# Processing Record 44 of Set 11 | macia
# Processing Record 45 of Set 11 | tiruchchendur
# Processing Record 46 of Set 11 | saint-jean-de-maurienne
# Processing Record 47 of Set 11 | acapulco
# Processing Record 48 of Set 11 | moctezuma
# Processing Record 49 of Set 11 | maunatlala
# Processing Record 50 of Set 11 | boma
# Processing Record 1 of Set 12 | kloulklubed
# Processing Record 2 of Set 12 | haverfordwest
# Processing Record 3 of Set 12 | teya
# Processing Record 4 of Set 12 | tsabong
# Processing Record 5 of Set 12 | sao felix do xingu
# Processing Record 6 of Set 12 | imbituba
# Processing Record 7 of Set 12 | adeje
# Processing Record 8 of Set 12 | saint george
# Processing Record 9 of Set 12 | les cayes
# Processing Record 10 of Set 12 | kundian
# Processing Record 11 of Set 12 | mbandaka
# Processing Record 12 of Set 12 | port hawkesbury
# Processing Record 13 of Set 12 | baruun-urt
# Processing Record 14 of Set 12 | atar
# Processing Record 15 of Set 12 | sur
# Processing Record 16 of Set 12 | makat
# Processing Record 17 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 12 | kabalo
# Processing Record 19 of Set 12 | teahupoo
# Processing Record 20 of Set 12 | burnie
# Processing Record 21 of Set 12 | fare
# Processing Record 22 of Set 12 | grindavik
# Processing Record 23 of Set 12 | namasuba
# Processing Record 24 of Set 12 | nanortalik
# Processing Record 25 of Set 12 | beypur
# City not found. Skipping...
# Processing Record 26 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 27 of Set 12 | araouane
# Processing Record 28 of Set 12 | sembakung
# Processing Record 29 of Set 12 | tobane
# Processing Record 30 of Set 12 | ulaangom
# Processing Record 31 of Set 12 | ibicarai
# Processing Record 32 of Set 12 | tautira
# Processing Record 33 of Set 12 | kadan
# Processing Record 34 of Set 12 | clarksburg
# Processing Record 35 of Set 12 | teknaf
# Processing Record 36 of Set 12 | kedrovyy
# Processing Record 37 of Set 12 | nyagan
# Processing Record 38 of Set 12 | murchison
# Processing Record 39 of Set 12 | cacu
# Processing Record 40 of Set 12 | opobo
# City not found. Skipping...
# Processing Record 41 of Set 12 | kariba
# Processing Record 42 of Set 12 | la ronge
# Processing Record 43 of Set 12 | fort nelson
# Processing Record 44 of Set 12 | malumfashi
# Processing Record 45 of Set 12 | shitanjing
# Processing Record 46 of Set 12 | riachao das neves
# Processing Record 47 of Set 12 | bubaque
# Processing Record 48 of Set 12 | pervomayskoye
# Processing Record 49 of Set 12 | gat
# Processing Record 50 of Set 12 | darhan
# Processing Record 1 of Set 13 | coracora
# Processing Record 2 of Set 13 | coruripe
# Processing Record 3 of Set 13 | yermakovskoye
# Processing Record 4 of Set 13 | ghatampur
# Processing Record 5 of Set 13 | dauphin
# Processing Record 6 of Set 13 | nombre de dios
# Processing Record 7 of Set 13 | tuxpan
# Processing Record 8 of Set 13 | gouyave
# Processing Record 9 of Set 13 | ust-shonosha
# Processing Record 10 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 11 of Set 13 | russell
# Processing Record 12 of Set 13 | tapes
# Processing Record 13 of Set 13 | saint anthony
# Processing Record 14 of Set 13 | emerald
# Processing Record 15 of Set 13 | bandarbeyla
# Processing Record 16 of Set 13 | navrongo
# Processing Record 17 of Set 13 | praia da vitoria
# Processing Record 18 of Set 13 | semporna
# Processing Record 19 of Set 13 | canazas
# Processing Record 20 of Set 13 | miracema do tocantins
# Processing Record 21 of Set 13 | waiuku
# Processing Record 22 of Set 13 | buraydah
# Processing Record 23 of Set 13 | nouadhibou
# Processing Record 24 of Set 13 | nabire
# Processing Record 25 of Set 13 | sarahan
# Processing Record 26 of Set 13 | niamey
# Processing Record 27 of Set 13 | vega de alatorre
# Processing Record 28 of Set 13 | usinsk
# Processing Record 29 of Set 13 | ajdabiya
# Processing Record 30 of Set 13 | gizo
# Processing Record 31 of Set 13 | cocobeach
# Processing Record 32 of Set 13 | aksarka
# Processing Record 33 of Set 13 | pekan
# Processing Record 34 of Set 13 | san policarpo
# Processing Record 35 of Set 13 | pierre
# Processing Record 36 of Set 13 | buckeye
# Processing Record 37 of Set 13 | rivers
# Processing Record 38 of Set 13 | shingu
# Processing Record 39 of Set 13 | rio verde de mato grosso
# Processing Record 40 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 13 | camopi
# Processing Record 42 of Set 13 | kamenka
# Processing Record 43 of Set 13 | anori
# Processing Record 44 of Set 13 | napasar
# Processing Record 45 of Set 13 | namatanai
# Processing Record 46 of Set 13 | crotone
# Processing Record 47 of Set 13 | bitung
# Processing Record 48 of Set 13 | caravelas
# Processing Record 49 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 13 | talnakh
# Processing Record 1 of Set 14 | araguari
# Processing Record 2 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 14 | tudela
# Processing Record 4 of Set 14 | iracoubo
# Processing Record 5 of Set 14 | noyabrsk
# Processing Record 6 of Set 14 | sri aman
# Processing Record 7 of Set 14 | sambava
# Processing Record 8 of Set 14 | cabedelo
# Processing Record 9 of Set 14 | gallup
# Processing Record 10 of Set 14 | arlit
# Processing Record 11 of Set 14 | ostersund
# Processing Record 12 of Set 14 | yar-sale
# Processing Record 13 of Set 14 | flinders
# Processing Record 14 of Set 14 | elliot lake
# Processing Record 15 of Set 14 | ulladulla
# Processing Record 16 of Set 14 | setermoen
# Processing Record 17 of Set 14 | bogdanovich
# Processing Record 18 of Set 14 | tabou
# Processing Record 19 of Set 14 | shahr-e babak
# Processing Record 20 of Set 14 | fatehpur chaurasi
# Processing Record 21 of Set 14 | imeni zhelyabova
# Processing Record 22 of Set 14 | hendijan
# City not found. Skipping...
# Processing Record 23 of Set 14 | lufilufi
# Processing Record 24 of Set 14 | hurricane
# Processing Record 25 of Set 14 | cuite
# Processing Record 26 of Set 14 | el badari
# City not found. Skipping...
# Processing Record 27 of Set 14 | igarape-acu
# City not found. Skipping...
# Processing Record 28 of Set 14 | westport
# Processing Record 29 of Set 14 | karaton
# Processing Record 30 of Set 14 | taoudenni
# Processing Record 31 of Set 14 | rorvik
# Processing Record 32 of Set 14 | cockburn town
# Processing Record 33 of Set 14 | letterkenny
# Processing Record 34 of Set 14 | grand-lahou
# Processing Record 35 of Set 14 | biak
# Processing Record 36 of Set 14 | nuuk
# Processing Record 37 of Set 14 | comodoro rivadavia
# Processing Record 38 of Set 14 | tobermory
# Processing Record 39 of Set 14 | chapais
# Processing Record 40 of Set 14 | harper
# Processing Record 41 of Set 14 | eyl
# Processing Record 42 of Set 14 | kodinsk
# Processing Record 43 of Set 14 | shenxian
# Processing Record 44 of Set 14 | durham
# Processing Record 45 of Set 14 | solone
# Processing Record 46 of Set 14 | florence
# Processing Record 47 of Set 14 | alugan
# Processing Record 48 of Set 14 | tamandare
# Processing Record 49 of Set 14 | sol-iletsk
# Processing Record 50 of Set 14 | harrismith
# Processing Record 1 of Set 15 | bafq
# Processing Record 2 of Set 15 | aykhal
# Processing Record 3 of Set 15 | walvis bay
# Processing Record 4 of Set 15 | camocim
# Processing Record 5 of Set 15 | beruwala
# Processing Record 6 of Set 15 | natal
# Processing Record 7 of Set 15 | conakry
# Processing Record 8 of Set 15 | marsa matruh
# Processing Record 9 of Set 15 | muli
# Processing Record 10 of Set 15 | nagorsk
# Processing Record 11 of Set 15 | vaitape
# Processing Record 12 of Set 15 | mattru
# Processing Record 13 of Set 15 | sept-iles
# Processing Record 14 of Set 15 | atagay
# Processing Record 15 of Set 15 | ifakara
# Processing Record 16 of Set 15 | inzhavino
# Processing Record 17 of Set 15 | ugoofaaru
# Processing Record 18 of Set 15 | plaster rock
# Processing Record 19 of Set 15 | greensboro
# Processing Record 20 of Set 15 | svolvaer
# Processing Record 21 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 15 | vama
# Processing Record 23 of Set 15 | acarau
# Processing Record 24 of Set 15 | pangody
# Processing Record 25 of Set 15 | birao
# Processing Record 26 of Set 15 | itambacuri
# Processing Record 27 of Set 15 | zverinogolovskoye
# Processing Record 28 of Set 15 | sao gabriel da cachoeira
# Processing Record 29 of Set 15 | atambua
# Processing Record 30 of Set 15 | watsa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Akdepe      TM  42.0551   59.3788     75.29        28           0
# 1   Mataura      NZ -46.1927  168.8643     43.48        95          80
# 2    Tashla      RU  51.7716   52.7427     74.03        51           9
# 3    Touros      BR  -5.1989  -35.4608     79.70        74           5
# 4    Nyurba      RU  63.2842  118.3319     63.18        60         100
# 5   Ushuaia      AR -54.8000  -68.3000     46.06        46          20
# 6  Ust-Maya      RU  60.4167  134.5333     63.63        61          95
# 7  Marathon      US  44.9000  -89.7668     75.24        47          75
# 8   Waipawa      NZ -41.4122  175.5153     49.46        76          94
# 9  Hermanus      ZA -34.4187   19.2345     56.89        79          94
#
#    Wind Speed Current Description
# 0       10.07           clear sky
# 1        2.82       broken clouds
# 2        4.38           clear sky
# 3       19.42           clear sky
# 4        4.99     overcast clouds
# 5       17.27          few clouds
# 6        4.76     overcast clouds
# 7       11.50       broken clouds
# 8        3.76     overcast clouds
# 9        2.19     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label = "City_ID")
